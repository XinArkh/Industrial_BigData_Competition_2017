# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
data1 = pd.read_csv('processed/15_data.csv')
data2 = pd.read_csv('processed/21_data.csv')
# data_labels = data['frozen']

# %%
plt.scatter(data1['wind_speed'], data1['power'], c=data1['frozen'], s=0.1, cmap='RdBu')

# %%
plt.scatter(data2['wind_speed'], data2['power'], c=data2['frozen'], cmap='RdBu')

# %%
plt.scatter(data1['pitch1_angle'], data1['power'], c=data1['frozen'], s=0.1, cmap='RdBu')

# %%
plt.scatter(data1['pitch1_speed'], data1['power'], c=data1['frozen'], s=0.1, cmap='RdBu')

# %%
plt.subplot(2, 3, 1)
plt.scatter(data1['wind_speed'], data1['power'], c=data1['frozen'], s=0.2, cmap='RdBu')
plt.title('wind_speed-power')
plt.subplot(2, 3, 2)
plt.scatter(data1['pitch1_angle'], data1['power'], c=data1['frozen'], s=0.2, cmap='RdBu')
plt.title('pitch1_angle-power')
plt.subplot(2, 3, 3)
plt.scatter(data1['pitch1_speed'], data1['power'], c=data1['frozen'], s=0.2, cmap='RdBu')
plt.title('pitch1_speed-power')
plt.subplot(2, 3, 4)
plt.scatter(data1['yaw_speed'], data1['power'], c=data1['frozen'], s=0.2, cmap='RdBu')
plt.title('yaw_speed-power')
plt.subplot(2, 3, 5)
plt.scatter(data1['environment_tmp'], data1['power'], c=data1['frozen'], s=0.2, cmap='RdBu')
plt.title('environment_tmp-power')
plt.subplot(2, 3, 6)
plt.scatter(data1['pitch1_ng5_DC'], data1['power'], c=data1['frozen'], s=0.2, cmap='RdBu')
plt.title('pitch1_ng5_DC-power')
# Out:
# Text(0.5,1,'pitch1_ng5_DC-power')

# %%
plt.scatter(data1['generator_speed'], data1['power'], c=data1['frozen'], cmap='RdBu')

# %%
plt.scatter(data2[data2['frozen']==0]['generator_speed'], data2[data2['frozen']==0]['power'], s=0.1, cmap='RdBu')
plt.scatter(data2[data2['frozen']==1]['generator_speed'], data2[data2['frozen']==1]['power'], s=0.1, cmap='RdBu')

# %%
plt.scatter(data2['yaw_speed'], data2['power'], c=data2['frozen'], cmap='RdBu')

# %%
plt.scatter(data1['yaw_speed'], data1['power'], c=data1['frozen'], cmap='RdBu')

# %%
plt.scatter(data1['pitch1_speed'], data1['power'], c=data1['frozen'], cmap='RdBu')

# %%
plt.subplot(2, 3, 5)
plt.scatter(data1['pitch1_ng5_DC'], data1['power'], c=data1['frozen'], s=0.2, cmap='RdBu')

# %%
plt.scatter(data1['pitch1_ng5_DC'], data1['pitch2_ng5_DC'], c=data1['frozen'], s=0.1, cmap='RdBu')

# %%
data = pd.concat([data1, data2])

# %%
data.shape
# Out:
# (553715, 29)

# %%
plt.scatter(data['wind_speed'], data['power'], c=data['frozen'], cmap='RdBu')

# %%
plt.scatter(data['int_tmp'], data['power'], c=data['frozen'], cmap='RdBu')

# %%
np.any(list(data1['time'][:-1]) > list(data1['time'][1:]))
# Out:
# False

# %%
data1['time'][0] < data1['time'][1]
# Out:
# True

# %%
type(data1['time'][0])
# Out:
# str

# %%
from datetime import datetime

# %%
datetime.strptime(data1['time'][0], '%Y-%m-%d %H:%M:%S')
# Out:
# datetime.datetime(2015, 11, 1, 20, 20, 16)

# %%
tmp = []
for i in range(10):
    tmp.append(datetime.strptime(data1['time'][i], '%Y-%m-%d %H:%M:%S'))

# %%
tmp
# Out:
# [datetime.datetime(2015, 11, 1, 20, 20, 16),
#  datetime.datetime(2015, 11, 1, 20, 20, 23),
#  datetime.datetime(2015, 11, 1, 20, 20, 30),
#  datetime.datetime(2015, 11, 1, 20, 20, 37),
#  datetime.datetime(2015, 11, 1, 20, 20, 47),
#  datetime.datetime(2015, 11, 1, 20, 20, 54),
#  datetime.datetime(2015, 11, 1, 20, 21, 1),
#  datetime.datetime(2015, 11, 1, 20, 21, 8),
#  datetime.datetime(2015, 11, 1, 20, 21, 15),
#  datetime.datetime(2015, 11, 1, 20, 21, 22)]

# %%
np.mean(tmp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-bc645afefdf1> in <module>()
# ----> 1 np.mean(tmp)
#
# e:\python\python3.5.2\lib\site-packages\numpy\core\fromnumeric.py in mean(a, axis, dtype, out, keepdims)
#    2918
#    2919     return _methods._mean(a, axis=axis, dtype=dtype,
# -> 2920                           out=out, **kwargs)
#    2921
#    2922
#
# e:\python\python3.5.2\lib\site-packages\numpy\core\_methods.py in _mean(a, axis, dtype, out, keepdims)
#      73             is_float16_result = True
#      74
# ---> 75     ret = umr_sum(arr, axis, dtype, out, keepdims)
#      76     if isinstance(ret, mu.ndarray):
#      77         ret = um.true_divide(
#
# TypeError: unsupported operand type(s) for +: 'datetime.datetime' and 'datetime.datetime'

# %%
type(data1['frozen'][0])
# Out:
# numpy.int64

# %%
tmp[0]+tmp[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-a8a13e43a5fe> in <module>()
# ----> 1 tmp[0]+tmp[1]
#
# TypeError: unsupported operand type(s) for +: 'datetime.datetime' and 'datetime.datetime'

# %%
np.any(data1['frozen'][:10])
# Out:
# False

# %%
data1['wind_speed'][:10].mean()
# Out:
# 2.063569044248939

# %%
type(data1[1:2])
# Out:
# pandas.core.frame.DataFrame

# %%
data1[1:2]
# Out:
#                   time  wind_speed  generator_speed     power  wind_direction  \
# 1  2015-11-01 20:20:23    1.911625         1.293394  2.313551       -2.010591
#
#    wind_direction_mean  yaw_position  yaw_speed  pitch1_angle  pitch2_angle  \
# 1             -1.61514     -0.655343   0.030804      0.195556      0.133333
#
#     ...    environment_tmp   int_tmp  pitch1_ng5_tmp  pitch2_ng5_tmp  \
# 1   ...          -0.421277 -0.002291        1.307692        1.123077
#
#    pitch3_ng5_tmp  pitch1_ng5_DC  pitch2_ng5_DC  pitch3_ng5_DC  group  frozen
# 1        0.783077           0.44           2.88           -2.6      1       0
#
# [1 rows x 29 columns]

# %%
data1.iloc[0][0]
# Out:
# '2015-11-01 20:20:16'

# %%
data1.columns
# Out:
# Index(['time', 'wind_speed', 'generator_speed', 'power', 'wind_direction',
#        'wind_direction_mean', 'yaw_position', 'yaw_speed', 'pitch1_angle',
#        'pitch2_angle', 'pitch3_angle', 'pitch1_speed', 'pitch2_speed',
#        'pitch3_speed', 'pitch1_moto_tmp', 'pitch2_moto_tmp', 'pitch3_moto_tmp',
#        'acc_x', 'acc_y', 'environment_tmp', 'int_tmp', 'pitch1_ng5_tmp',
#        'pitch2_ng5_tmp', 'pitch3_ng5_tmp', 'pitch1_ng5_DC', 'pitch2_ng5_DC',
#        'pitch3_ng5_DC', 'group', 'frozen'],
#       dtype='object')

# %%
type(data1['time'])
# Out:
# pandas.core.series.Series

# %%
import re

# %%
Y, m, d, H, M, S = re.split('-| |:', data1['time'][0])

# %%
M
# Out:
# '20'

# %%
type(re.split('-| |:', data1['time'][0]))
# Out:
# list

# %%
H, M = [int(item) for item in re.split('-| |:', data1['time'][0])[3:5]]

# %%
H
# Out:
# 20

# %%
titles = data1.columns

# %%
data1[titles[1:-1]][:10].mean()
# Out:
# wind_speed             2.063569
# generator_speed        1.283755
# power                  2.434901
# wind_direction        -1.721426
# wind_direction_mean   -0.617995
# yaw_position          -0.624507
# yaw_speed              0.428478
# pitch1_angle           1.236444
# pitch2_angle           1.206222
# pitch3_angle           1.234667
# pitch1_speed          -0.720000
# pitch2_speed          -0.712000
# pitch3_speed          -0.608000
# pitch1_moto_tmp        0.748300
# pitch2_moto_tmp        0.617500
# pitch3_moto_tmp        0.595400
# acc_x                 -0.236573
# acc_y                 -0.447143
# environment_tmp       -0.405970
# int_tmp                0.001151
# pitch1_ng5_tmp         1.307692
# pitch2_ng5_tmp         1.114615
# pitch3_ng5_tmp         0.783077
# pitch1_ng5_DC          0.560000
# pitch2_ng5_DC          0.392000
# pitch3_ng5_DC          0.120000
# group                  1.000000
# dtype: float64

# %%
a = []
a.append(data1[titles[1:-1]][:10].mean())

# %%
type(a)
# Out:
# list

# %%
len(titles[1:-1])
# Out:
# 27

# %%
data1[titles[1][:10]].mean()
# Out:
# -0.19040813043705354

# %%
data = pd.read_csv('processed/15_avg_data.csv')

# %%
plt.scatter(data['wind_speed'], data['power'], c=data['frozen'], cmap='RdBu')

# %%
data = pd.read_csv('processed/21_avg_data.csv')
plt.scatter(data['wind_speed'], data['power'], c=data['frozen'], cmap='RdBu')

# %%
data = pd.read_csv('processed/15_avg10_data.csv')
plt.scatter(data['wind_speed'], data['power'], c=data['frozen'], cmap='RdBu')

# %%
data = pd.read_csv('processed/21_avg10_data.csv')
plt.scatter(data['wind_speed'], data['power'], c=data['frozen'], cmap='RdBu')

# %%
type(data['power'][0])
# Out:
# numpy.float64

# %%
ans = data['power'] > 2

# %%
ans.shape
# Out:
# (28766,)

# %%
data.shape
# Out:
# (28766, 29)

# %%
lowPower = data.loc[data['power'] > 2]

# %%
ans
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
# 5         True
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23        True
# 24        True
# 25        True
# 26        True
# 27        True
# 28        True
# 29        True
#          ...
# 28736    False
# 28737    False
# 28738    False
# 28739    False
# 28740    False
# 28741    False
# 28742    False
# 28743    False
# 28744    False
# 28745    False
# 28746    False
# 28747    False
# 28748    False
# 28749    False
# 28750    False
# 28751    False
# 28752    False
# 28753    False
# 28754    False
# 28755    False
# 28756    False
# 28757    False
# 28758    False
# 28759    False
# 28760    False
# 28761    False
# 28762    False
# ...

# %%
data.iloc[data['power'] > 2]
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-126-4ce57ad7bd0c> in <module>()
# ----> 1 data.iloc[data['power'] > 2]
#
# e:\python\python3.5.2\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# e:\python\python3.5.2\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2084
#    2085         if com.is_bool_indexer(key):
# -> 2086             self._validate_key(key, axis)
#    2087             return self._getbool_axis(key, axis=axis)
#    2088
#
# e:\python\python3.5.2\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
# ...

# %%
type(lowPower)
# Out:
# pandas.core.frame.DataFrame

# %%
data.to_csv('test.csv')

# %%
data = pd.read_csv('processed/15_avg10_lowPower_data.csv')
plt.scatter(data['wind_speed'], data['power'], c=data['frozen'], cmap='RdBu')

# %%
data = pd.read_csv('processed/15_avg1_lowPower_data.csv')
plt.scatter(data['wind_speed'], data['power'], c=data['frozen'], s=0.1, cmap='RdBu')

# %%
len(data[data['frozen']==1])
# Out:
# 1274

# %%
data = pd.read_csv('processed/21_avg1_lowPower_data.csv')
plt.scatter(data['wind_speed'], data['power'], c=data['frozen'], s=0.1, cmap='RdBu')

# %%
data.shape
# Out:
# (25672, 29)

# %%
X = data[['wind_speed', 'power']]

# %%
X.shape
# Out:
# (25672, 2)

# %%
X = X[:, np.newaxis]

# %%
y = data['power']

# %%
y.shape
# Out:
# (25672,)

# %%
type(y[0])
# Out:
# numpy.float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (19254, 1)
# (19254,)
# (6418, 1)
# (6418,)

# %%
data.values[[0, 1]]
# Out:
# array([['2015-11-01 20:30:03', 1.4277548738691632, 1.2583757696895748,
#         1.9727163776571242, -1.1455831419900924, -0.8333394635533321,
#         0.21225429841389284, 0.004225511056126126, 0.4146031746031747,
#         0.4286243386243387, 0.4396296296296293, -0.00952380952380952,
#         -0.013333333333333345, -0.008571428571428574, 0.9254523809523808,
#         1.0184285714285717, 1.094464285714286, 0.5963717461204937,
#         0.6510454905407029, -0.41150846652414497, -0.2858426620705918,
#         1.018608058608056, 0.8600000000000001, 0.9978021978021978,
#         0.6538095238095238, 0.6742857142857143, 1.1214285714285714,
#         15.583333333333336, 0],
#        ['2015-11-01 20:40:02', 0.9351487755134824, 1.2499968248068558,
#         1.2239638107067308, -0.12358497436242175, -0.11111458972359192,
#         0.2123471834755348, 0.005134430949555296, 0.21953878406708607,
#         0.24914046121593256, 0.20670859538784053, 0.049056603773584916,
# ...
